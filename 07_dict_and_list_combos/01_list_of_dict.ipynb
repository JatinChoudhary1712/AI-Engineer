# %%
user = [
    {"name" : "Jatin"  , "Rollno" : 2121321},
    {"name" : "Jassi" , "Rollno" : 2121322}
]

# %%
user[0]
# Out:
# {'name': 'Jatin', 'Rollno': 2121321}

# %%
user[1]
# Out:
# {'name': 'Jassi', 'Rollno': 2121322}
