# %%
class Animal:
    def sound(self):
        print("Animal makes a sound")

class Dog(Animal):
    def sound(self):
        print("Dog make Bark sound")

# %%
d = Dog()

# %%
d.sound()
# Out:
# Dog make Bark sound
