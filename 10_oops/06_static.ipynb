# %%
class Car:
    wheels = 4   # static variable

c1 = Car()
c2 = Car()

print(c1.wheels)  # 4
print(c2.wheels)  # 4
# Out:
# 4
# 4

# %%
class Car:
    @staticmethod 
    def info():
        return "Cars have engines"

print(Car.info())
# Out:
# Cars have engines
