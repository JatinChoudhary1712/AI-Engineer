# %% [markdown]
# * `type()` → checks **exact type only**
# * `isinstance()` → checks **type + its parent (inheritance)**

# %%
a=5 
type(a)
# Out:
# int

# %%
isinstance(a, int)
# Out:
# True

# %%
a = [1,2]
a.append(3)   # same list changed

# %%
a
# Out:
# [1, 2, 3]

# %%
a = "hi"
a = a + "!"   # new string made

# %%
a
# Out:
# 'hi!'

# %% [markdown]
# * **Mutable** → can change in-place (same object)
# * **Immutable** → cannot change; creates a new object

# %%
a = [1,2]
a.append(3)   # same list changed

# %%
a = "hi"
a = a + "!"   # new string made
