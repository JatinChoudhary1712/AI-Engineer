# %%
with open("skills.txt" , "w") as file:
    file.write("Python")
    file.write("\nSQL")
    file.write("\nMachine Learning")

# %%
user = {
    "name": "Jatin",
    "role": "AI Engineer"
}

import json 

with open("user.json" , "w") as file:
    json.dump(user , file)
