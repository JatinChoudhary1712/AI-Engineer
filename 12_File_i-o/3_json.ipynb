# %% [markdown]
# Dump

# %%
import json 

data = {
    "name": "Jatin",
    "age": 22
}

with open("user.json" , "w") as file:
    json.dump(data , file)

# %% [markdown]
# Load

# %%
import json

with open("user.json", "r") as file:
    data = json.load(file)

print(data)
# Out:
# {'name': 'Jatin', 'age': 22}
