# %%
import os

# %%
import os

print(os.listdir())
# Out:
# ['0_practice.ipynb', '1_read_write_append.ipynb', '2_workling_csv.ipynb', '3_json.ipynb', '4_os.ipynb', 'data.txt', 'notes.txt', 'skills.txt', 'students.csv', 'user.json', 'user1.json']

# %%
os.mkdir("new_folder")

# %%
os.makedirs("data/images/cats")
