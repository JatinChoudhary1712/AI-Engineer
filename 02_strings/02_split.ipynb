# %% [markdown]
# 🔹 split()
# - Break string into list

# %%
str = "a b c"
str.split(" ")
# Out:
# ['a', 'b', 'c']

# %%
"hello world".split()
# Out:
# ['hello', 'world']

# %%
"one--two--three".split("--")
# Out:
# ['one', 'two', 'three']

# %%
"python".split(",")
# Out:
# ['python']
