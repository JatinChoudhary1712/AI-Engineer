# %% [markdown]
# String slicing: s[start:stop:step]
#
# - start → where to begin (included)
# - stop → where to end (excluded)
# - step → jump size

# %%
s = "python"
s[1:5:2]
# Out:
# 'yh'

# %%
str = "1234567"
str[0:7:3]
# Out:
# '147'
