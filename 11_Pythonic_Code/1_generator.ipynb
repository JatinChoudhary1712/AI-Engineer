# %% [markdown]
# Generator

# %%
nums = (x*x for x in range(5))

print(next(nums))
# Out:
# 0

# %%
print(next(nums))
# Out:
# 1

# %%
print(next(nums))
# Out:
# 4

# %%
def demo(): 
    yield 1 
    yield "My name is Jatin"
    yield 3

# %%
x = demo()

# %%
print(next(x))
# Out:
# 1

# %%
print(next(x))
# Out:
# My name is Jatin
