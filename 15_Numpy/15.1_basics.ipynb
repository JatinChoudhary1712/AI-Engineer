# %%
import numpy as np 

my_list = [1,2,3,4]

my_list = my_list * 2 

print(my_list)
# Out:
# [1, 2, 3, 4, 1, 2, 3, 4]

# %%
array = np.array([1,2,3,4])

array = array * 2 

print(array)
# Out:
# [2 4 6 8]

# %% [markdown]
# ---

# %% [markdown]
# 1-D array

# %%
arr = np.array([1,2,3,4])

# %%
arr
# Out:
# array([1, 2, 3, 4])

# %% [markdown]
# ---

# %% [markdown]
# 2-D array

# %%
arr2 = np.array([[1,2,3],
                [4,5,6]])

# %%
arr2
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %% [markdown]
# ---

# %% [markdown]
# np.zero()

# %%
np.zeros(5)
# Out:
# array([0., 0., 0., 0., 0.])

# %% [markdown]
# np.zeros() -> 2D

# %%
np.zeros((2,3))
# Out:
# array([[0., 0., 0.],
#        [0., 0., 0.]])

# %% [markdown]
# ----

# %% [markdown]
# np.ones()

# %%
np.ones(5)
# Out:
# array([1., 1., 1., 1., 1.])

# %%
np.ones((2,3))
# Out:
# array([[1., 1., 1.],
#        [1., 1., 1.]])

# %% [markdown]
# np.eye()

# %%
np.eye(3)
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])
