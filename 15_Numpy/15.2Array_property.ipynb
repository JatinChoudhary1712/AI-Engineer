# %%
import numpy as np

# %%
arr = np.array([
    [1,2,3],
    [4,5,6]
])

# %%
arr
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %% [markdown]
# 1. shape
#
# Tells dimensions in:

# %%
np.shape(arr)
# Out:
# (2, 3)

# %% [markdown]
# 2. ndim
#
# Means: number of dimensions

# %%
print(arr.ndim)
# Out:
# 2

# %% [markdown]
# 3. dtype
#
# Means:
#
# data type

# %%
print(arr.dtype)
# Out:
# int32
