# %% [markdown]
# .keys()
# - Returns all keys
# - d.keys() → ["a", "b"]

# %%
d = {"a" : 1 , "b" : 2 , "c" : 3}

# %%
d.keys()
# Out:
# dict_keys(['a', 'b', 'c'])

# %%
d.values()
# Out:
# dict_values([1, 2, 3])

# %%
d.items()
# Out:
# dict_items([('a', 1), ('b', 2), ('c', 3)])

# %%
d.get("a")
# Out:
# 1
