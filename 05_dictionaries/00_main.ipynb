# %% [markdown]
# ### When to prefer tuples over lists
# - Data should not change → use tuple (e.g. coordinates (x, y))
# - Faster than lists (slightly, due to immutability)
# - Safe data (no accidental modification)
