# %% [markdown]
# - range() → numbers loop
# - enumerate() → index + value
# - zip() → pair elements

# %% [markdown]
# -------------------------------------------------------

# %% [markdown]
# range() → generates sequence of numbers

# %%
for i in range(1, 5):
    print(i)   # 1,2,3,4
# Out:
# 1
# 2
# 3
# 4

# %% [markdown]
# enumerate() → gives index + value

# %%
lst = ["a", "b", "c"]

for i, v in enumerate(lst):
    print(i, v)   # (0,a), (1,b), (2,c)
# Out:
# 0 a
# 1 b
# 2 c

# %% [markdown]
# zip() → combines multiple iterables

# %%
names = ["Jatin", "Rahul"]
ages = [22, 25]

for n, a in zip(names, ages):
    print(n, a)   # Jatin 22, Rahul 25
# Out:
# Jatin 22
# Rahul 25
