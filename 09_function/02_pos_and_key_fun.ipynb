# %%
def intro(name , age ,city ):
    print(f"name is {name} , age {age} and he lives in {city}")
    
intro("jatin" , 22 , "chandigarh")
# Out:
# name is jatin , age 22 and he lives in chandigarh

# %%
def intro(name , age ,city ):
    print(f"name is {name} , age {age} and he lives in {city}")
    
intro(name = "jatin" ,city = "chandigarh", age = 22  )
# Out:
# name is jatin , age 22 and he lives in chandigarh

# %% [markdown]
# Notes : Mix allowed → but order rule strict

# %%
def sum(a,b,c):
    print(a+b+c)

sum(1, 2 , c = 6)
# Out:
# 9
