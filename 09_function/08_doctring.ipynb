# %% [markdown]
# Description of a function/class (written inside it)

# %%
def add(a, b):
    """This function adds two numbers"""
    return a + b

# %%
print(add.__doc__)
# Out:
# This function adds two numbers

# %% [markdown]
# ---

# %% [markdown]
# Why use
# - Helps others understand your code
# - Used in documentation (important in real projects)
