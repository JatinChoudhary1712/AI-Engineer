# %% [markdown]
# - return → send value back
# - unpacking → break values into variables

# %% [markdown]
# ---

# %% [markdown]
# Return

# %%
def sum(a,b):
    sum = a + b
    return sum

# %%
sum(1,2)
# Out:
# 3

# %% [markdown]
# ---

# %% [markdown]
# Unpacking

# %%
a, b = (1, 2)
print(a)   # 1
print(b)   # 2
# Out:
# 1
# 2
