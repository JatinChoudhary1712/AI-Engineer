# %%
import pandas as pd

data = {
    "Department": ["IT", "HR", "IT", "HR", "Sales"],
    "Employee": ["Jatin", "Rahul", "Aman", "Priya", "Karan"],
    "Salary": [50000, 40000, 60000, 45000, 70000]
}

df = pd.DataFrame(data)

print(df)
# Out:
#   Department Employee  Salary
# 0         IT    Jatin   50000
# 1         HR    Rahul   40000
# 2         IT     Aman   60000
# 3         HR    Priya   45000
# 4      Sales    Karan   70000

# %%
df.groupby("Department")

# %%
df.groupby("Department")["Salary"].mean()
# Out:
# Department
# HR       42500.0
# IT       55000.0
# Sales    70000.0
# Name: Salary, dtype: float64

# %%
df.groupby("Department")["Salary"].sum()
# Out:
# Department
# HR        85000
# IT       110000
# Sales     70000
# Name: Salary, dtype: int64

# %%
import pandas as pd

df = pd.DataFrame({
    "Date": ["2026-01-10", "2026-02-15", "2026-03-20"]
})

print(df)
# Out:
#          Date
# 0  2026-01-10
# 1  2026-02-15
# 2  2026-03-20

# %%
# Out:
#   Cell In[6], line 1
#     python -m venv venv
#               ^
# SyntaxError: invalid syntax
