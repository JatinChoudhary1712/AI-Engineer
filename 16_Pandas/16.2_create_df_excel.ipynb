# %%
import pandas as pd

# %%
df = pd.read_excel(r"C:\Users\Jatin Code\GENAI\phase-01-python\employees.xlsx")

# %%
df.head()
# Out:
#    emp_id   name department       city  salary  experience joining_date
# 0     101  Jatin         AI      Delhi   75000           2   2024-01-15
# 1     102  Rahul         HR     Mumbai   50000           3   2023-06-10
# 2     103   Aman         AI  Bangalore   82000           1   2025-02-01
# 3     104  Priya      Sales      Delhi   45000           4   2022-09-21
# 4     105   Neha         HR       Pune   52000           2   2024-03-11

# %%
data = {
    "name" : ["Jatin" , "Aryan" , "Rahul"],
    "marks" : [90 , 80 , 95],
    "city" : ["Delhi" , "Mumbai" , "Pune"]
}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#     name  marks    city
# 0  Jatin     90   Delhi
# 1  Aryan     80  Mumbai
# 2  Rahul     95    Pune

# %%
df["grade"] = ['A' , 'B' , 'C']

# %%
df
# Out:
#     name  marks    city grade
# 0  Jatin     90   Delhi     A
# 1  Aryan     80  Mumbai     B
# 2  Rahul     95    Pune     C

# %%
df.describe()
# Out:
#            marks
# count   3.000000
# mean   88.333333
# std     7.637626
# min    80.000000
# 25%    85.000000
# 50%    90.000000
# 75%    92.500000
# max    95.000000

# %% [markdown]
# loc and  iloc

# %%
import pandas as pd

data = {
    "name": ["Jatin", "Aryan", "Rahul"],
    "marks": [90, 80, 95],
    "city": ["Delhi", "Mumbai", "Pune"]
}

df = pd.DataFrame(data)

print(df)
# Out:
#     name  marks    city
# 0  Jatin     90   Delhi
# 1  Aryan     80  Mumbai
# 2  Rahul     95    Pune

# %%
df.iloc[0,1]
# Out:
# 90

# %% [markdown]
# df.loc[row_label, column_label]

# %%
df.loc[0, "name"]
# Out:
# 'Jatin'
