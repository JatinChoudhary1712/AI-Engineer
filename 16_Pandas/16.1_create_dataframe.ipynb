# %%
import pandas as pd

# %%
data = {
    "name": ["Jatin", "Aman", "Rahul"],
    "age": [22, 21, 24],
    "city": ["Delhi", "Mumbai", "Pune"]
}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#     name  age    city
# 0  Jatin   22   Delhi
# 1   Aman   21  Mumbai
# 2  Rahul   24    Pune
