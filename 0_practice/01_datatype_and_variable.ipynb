# %%
x = "42"
y = int(x) + 8
print(y)
print(type(y))
# Out:
# 50
# <class 'int'>

# %%
print(bool(0))
print(bool(""))
print(bool([]))
print(bool("False"))
# Out:
# False
# False
# False
# True

# %% [markdown]
# true , true , false , true

# %%
a = [1, 2, 3]
b = a
b.append(4)
print(a)
print(b)
print(a is b)  # [1,2,3] , [1,2,3,4] , True
# Out:
# [1, 2, 3, 4]
# [1, 2, 3, 4]
# True

# %%
x = 3.9
print(int(x))
print(round(x))
print(isinstance(x, (int, float)))
# Out:
# 3
# 4
# True

# %%
def greet(name, greeting="Hello"):
    return f"{greeting}, {name}!"

print(greet("Jatin"))
print(greet("Jatin", "Hey"))
print(greet(greeting="Yo", name="Claude")) #Hello Jatin hey Jatin yo claude
# Out:
# Hello, Jatin!
# Hey, Jatin!
# Yo, Claude!

# %%
def total(*numbers):
    return sum(numbers)

print(total(1, 2, 3))
print(total(10, 20))
print(total())      # 6 , 30 , 0
# Out:
# 6
# 30
# 0

# %%
def show_config(**kwargs):
    for k, v in kwargs.items():
        print(f"{k}={v}")

show_config(model="claude", max_tokens=1024, stream=True) # model = claude , max_tokens = 1024 , stream = True
# Out:
# model=claude
# max_tokens=1024
# stream=True

# %%
def get_stats(numbers):
    return min(numbers), max(numbers), sum(numbers) / len(numbers)

low, high, avg = get_stats([10, 20, 30, 40])
print(f"min={low} max={high} avg={avg}")
# Out:
# min=10 max=40 avg=25.0

# %% [markdown]
# ---

# %% [markdown]
# Write a lambda that takes a message dict and returns its `content` length.

# %%
msg = {"role": "user", "content": "What is RAG?"}
# use a lambda to get 12
length = lambda msg : len(msg["content"])
length(msg)
# Out:
# 12

# %%
def build_message(content, role="user", **extra):
        return {"content" : content , "role" : role }

# %%
build_message("Hello", role="system", tokens=5)
# Out:
# {'content': 'Hello', 'role': 'system'}

# %%
data = {
    "session_1": ["msg1", "msg2"],
    "session_2": ["msg3"],
    "session_3": ["msg4", "msg5", "msg6"],
}

# %%
length = len(data) -1
# Out:
# 3

# %%
def count_messages(data):
    total = 0
    for value in data.values():
        total += len(value)
    return total

# %%
count_messages(data)
# Out:
# 6

# %%
nums = [1, 5, 10, 15, 20] 
new = []
[new.append(i**2) for i in nums if i > 10]

new
# Out:
# [225, 400]

# %%
text = "python is easy and python is powerful"

text1 = text.split()

# %%
freq = {}
for i in text1: 
    if i in freq:
        freq[i] += 1 
    else : 
        freq[i] = 1

# %%
freq
# Out:
# {'python': 2, 'is': 2, 'easy': 1, 'and': 1, 'powerful': 1}

# %%
students = [
 {"name": "A", "marks": [80, 90]},
 {"name": "B", "marks": [70, 60]},
 {"name": "C", "marks": [90, 95]}
]

avg = {}

for student in students:
    name = student["name"]
    marks = student["marks"]
    
    avg[name] = sum(marks) / len(marks)

print(avg)
# Out:
# {'A': 85.0, 'B': 65.0, 'C': 92.5}

# %%
count = len(students)

# %%
for i in range(count):
    print(sum(students[i]['marks'])/2)
# Out:
# 85.0
# 65.0
# 92.5

# %%
for i in students:
    if students[i]['name'] not in avg:
        e
# Out:
#   Cell In[132], line 3
#
#     ^
# SyntaxError: incomplete input

# %%
def get_even(nums):
    return [i for i in nums if i % 2 == 0]

# %%
lst = [1, 2, 3, 4, 5, 6]

get_even(lst)
# Out:
# [2, 4, 6]

# %%
a = [1,2,3,4]
b = [3,4,5,6]

# %%
s1 = set(a)
s2 = set(b)

# %%
s1.union(s2)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
s1.intersection(s2)
# Out:
# {3, 4}
