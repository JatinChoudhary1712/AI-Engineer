# %% [markdown]
# 5. pop()
# - Removes + returns element
# - Default = last
# - Example: lst.pop() or lst.pop(1)

# %%
lst = [10,20 ,30 ,40]

# %%
lst.pop()
# Out:
# 40

# %%
lst.pop(1)
# Out:
# 20

# %%
lst
# Out:
# [10, 30]

# %%
lst.pop(0)
# Out:
# 10
